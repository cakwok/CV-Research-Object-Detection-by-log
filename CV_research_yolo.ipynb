# %% [markdown]
# <a href="https://colab.research.google.com/github/cakwok/CV-Research-Object-Detection-by-log/blob/main/CV_research_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Bruce
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# /content/drive/MyDrive/Colab Notebooks/Bruce
# Cloning into 'yolov7'...
# remote: Enumerating objects: 998, done.
# remote: Total 998 (delta 0), reused 0 (delta 0), pack-reused 998
# Receiving objects: 100% (998/998), 69.77 MiB | 12.79 MiB/s, done.
# Resolving deltas: 100% (465/465), done.
# Checking out files: 100% (104/104), done.

# %%
#%cd yolov7
#!wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7.pt
#!pip install -r requirements.txt

# %%
import os
#os.environ["DATASET_DIRECTORY"] = "/content/drive/MyDrive/Colab Notebooks/Bruce/datasets"
# !wandb disabled
# %cd /content/drive/MyDrive/Colab\ Notebooks/Bruce/yolov7
# !python train.py --batch 16 --epochs 55 --weights yolov7.pt --data "data/custom.yaml" --cfg cfg/training/yolov7.yaml --cache --img 600
# Out:
# /bin/bash: wandb: command not found
# /content/drive/MyDrive/Colab Notebooks/Bruce/yolov7
# YOLOR 🚀 2022-11-14 torch 1.12.1+cu113 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=True, cfg='cfg/training/yolov7.yaml', data='data/custom.yaml', device='', entity=None, epochs=55, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[600, 600], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp3', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=16, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !python detect.py --weights runs/train/exp3/weights/best.pt --source test/images/IMG-0402-resized.jpg
